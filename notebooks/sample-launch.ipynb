# %% [markdown]
# # Pyrrhus Jupyter Launch Sample
#
# This notebook is the default external notebook used by `bootstrap.sh`. Override it by setting `NOTEBOOK_URL` when you run the bootstrap one-liner.

# %%
import platform
from datetime import datetime, timezone

print("Pyrrhus JupyterLab is ready.")
print(f"Python: {platform.python_version()}")
print(f"UTC time: {datetime.now(timezone.utc).isoformat()}")

# %%
try:
    import pandas as pd
    pd.DataFrame(
        [
            {"component": "container", "default": "ghcr.io/liveaverage/pyrrhus-jupyter:slim"},
            {"component": "notebook", "default": "notebooks/sample-launch.ipynb"},
        ]
    )
except Exception as exc:
    print(f"Pandas is unavailable: {exc}")
